# %% [markdown]
# # Inputs and outputs

# %%
print('My name is Rickard')
# Out:
# My name is Rickard

# %%
name = 'Rickard'
print(f'Your name is {name}')
# Out:
# Your name is Rickard

# %%
name = input('What is your name?')
age = input('What is your age?')

print(f'{name} is {age} years old')
# Out:
# Rickard is 35 years old

# %% [markdown]
# # type coercion

# %%
gravity = 9.82
mass = float(input('Enter your weight in kg: '))

force = mass*gravity
print(f'{force = } N')
# Out:
# force = 785.6 N

# %%
print(f'{force = :.1f} N')
# Out:
# force = 785.6 N

# %% [markdown]
# # more types

# %%
radius = 7
geometry = 'circle'
is_unit_circle = False
screen_inches = 6.4

type(radius), type(geometry), type(is_unit_circle), type(screen_inches)

# %%
print('HEJ')
# Out:
# HEJ
