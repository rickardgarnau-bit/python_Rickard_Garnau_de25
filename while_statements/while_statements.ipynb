# %% [markdown]
# # While statements

# %%
n = 0
while n < 5:
    print(f'Hello {n}')
    n += 1
# Out:
# Hello 0
# Hello 1
# Hello 2
# Hello 3
# Hello 4

# %% [markdown]
# ### Example - oil leakage

# %%
birds = 80000
year = 0

while birds > 8000:
    print(f'Year {year} there were {birds:.0f} birds')
    birds /= 2
    year += 1

print(f'It takes {year} years for the birds to have 1/10 remaining')
# Out:
# Year 0 there were 80000 birds
# Year 1 there were 40000 birds
# Year 2 there were 20000 birds
# Year 3 there were 10000 birds
# It takes 4 years for the birds to have 1/10 remaining

# %% [markdown]
# ### Assignment operators

# %%
n =-9
while n <= 10:
    print(n, end=' ')
    n += 2
# Out:
# -9 -7 -5 -3 -1 1 3 5 7 9

# %% [markdown]
# ### Break statement

# %%
import random as rnd

while True:
    number1 = rnd.randint(1,10)
    number2 = rnd.randint(1,10)

    user_answer = int(input(f'What is {number1}*{number2}? '))
    if user_answer == number1*number2:
        print('Correct')
    else:
        print(f'{user_answer} is wrong')

    play_again = input('Wanna play again (y for yes)? ')

    if play_again != 'y':
        print('Have a nice day!')
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 import random as round
#       3 while True:
# ----> 4     number1 = rnd.randint(1,10)
#       5     number2 = rnd.randint(1,10)
#       7     user_answer = int(input(f'What is {number1}*{number2}? '))
#
# NameError: name 'rnd' is not defined
